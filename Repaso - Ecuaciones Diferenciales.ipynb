# %% [markdown]
# José Mauel Ramírez Araiza. 16/11/2023

# %% [markdown]
# # Repaso (Módulo 3)
# > Recordar que el tema principal del módulo son las ecuaciones diferenciales. Entonces, al finalizar este módulo, las competencias principales que deben tener ustedes es
# > - Resolver de forma numérica ecuaciones diferenciales ordinarias (EDO) de cualquier orden.
# > - Graficar soluciones de dichas EDO en diferentes representaciones.
# > - Interpretar o concluir acerca de las gráficas que se obtuvieron.

# %% [markdown]
# ___
# ## Ejemplo 1. Conejos vs. Ovejas.

# %% [markdown]
# Imaginemos que en un mismo ecosistema se encuentran conejos y ovejas. Supongamos, además, que ambas compiten por el mismo alimento (hierba) y que la cantidad total de alimento es limitada. Se ignoran otros factores como depredadores, efectos de temporada (estaciones), y otras fuentes de comida. El modelo de competición entre dos especies **Lotka-Volterra** nos sirve para describir este fenómeno.
#
# Dos fenómenos importantes:
# - Cada especie crecería hasta su capacidad máxima en ausencia de la otra especie. Esto se puede modelar con la ecuación logística para cada especie. Los conejos tienen una habilidad soprendente para reproducirse, entonces comparativamente deberían crecer más.
# - Cuando conejos y ovejas se encuentran, empieza la competencia. Algunas veces los conejos comen, pero las ovejas (al ser más grandes) ganarán el derecho a la comida la mayoría de las veces. Supondremos que dichos conflictos se dan a una tasa proporcional al tamaño de cada población (si hay dos veces más ovejas, la probabilidad de que un conejo encuentre a una oveja será el doble). Supondremos que dicha competencia disminuirá la tasa de crecimiento para cada especie, y el efecto será mayor para los conejos.

# %% [markdown]
# Con las consideraciones anteriores, un modelo específico es:
#
# \begin{align}
# \frac{dx_1}{dt} &= x_1(3-x_1-2x_2)\\
# \frac{dx_2}{dt} &= x_2(2-x_2-x_1),
# \end{align}
#
# donde $x_1(t)\geq 0$ es la población de conejos al instante $t$ y $x_2(t)\geq 0$ es la población de ovejas al instante $t$. Definimos $x=\left[x_1\quad x_2\right]^T$.
#
# Esta selección de coeficientes se tiene para recrear el escenario descrito. Sin embargo, este modelo se puede utilizar para estudiar competición entre especies en general y los coeficientes cambiarán en cada caso.

# %% [markdown]
# Simule el sistema para cada una de las siguientes condiciones iniciales. Para cada caso, obtenga gráficas de $x_1$ vs. $t$, $x_2$ vs. $t$ y $x_2$ vs. $x_1$. ¿Qué pasa con las poblaciones de conejos y de ovejas cuando $t\to\infty$? ¿Pueden coexistir?
#
# 1. $x(0)=\left[x_1(0)\quad x_2(0)\right]^T = [0.5 \quad 1]^T$.
# 2. $x(0)=\left[x_1(0)\quad x_2(0)\right]^T = [1 \quad 0.5]^T$.
# 3. $x(0)=\left[x_1(0)\quad x_2(0)\right]^T = [1.5 \quad 1]^T$.
# 4. $x(0)=\left[x_1(0)\quad x_2(0)\right]^T = [1 \quad 1.5]^T$.
# 5. $x(0)=\left[x_1(0)\quad x_2(0)\right]^T = [1 \quad 1]^T$.

# %%
from scipy.integrate import solve_ivp, odeint
import numpy as np
import numpy as np
def funcion(t, X):
    x1 = X[0]
    x2 = X[1]
    dx1=x1*(3-x1-2*x2)
    dx2 = x2*(2-x2-x1)
    dx = [dx1,dx2]
    return dx
t_span = [0,20]
x0 = np.array([0.5, 1])

# %%
g = solve_ivp(funcion,t_span, x0)
g
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.046e-01 ...  1.826e+01  2.000e+01]
#         y: [[ 5.000e-01  5.234e-01 ...  3.048e-07  5.829e-08]
#             [ 1.000e+00  1.050e+00 ...  2.000e+00  2.000e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 122
#      njev: 0
#       nlu: 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(g.t, g.y[0,:], label = "x1")
plt.plot(g.t, g.y[1,:], label = "x2")

plt.legend(loc="best")
plt.grid

plt.figure()
plt.plot(g.y[0, :], g.y[1, :], label = "X2-X1")

# %%
def funcion(t, X):
    x1 = X[0]
    x2 = X[1]
    dx1=x1*(3-x1-2*x2)
    dx2 = x2*(2-x2-x1)
    dx = [dx1,dx2]
    return dx
t_span = [0,20]
x0 = np.array([1, 0.5])
g = solve_ivp(funcion,t_span, x0)
g
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.046e-01 ...  1.973e+01  2.000e+01]
#         y: [[ 1.000e+00  1.101e+00 ...  3.002e+00  3.001e+00]
#             [ 5.000e-01  5.234e-01 ...  2.162e-08  1.645e-08]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 152
#      njev: 0
#       nlu: 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(g.t, g.y[0,:], label = "x1")
plt.plot(g.t, g.y[1,:], label = "x2")

plt.legend(loc="best")
plt.grid
plt.figure()
plt.plot(g.y[0, :], g.y[1, :], label = "X2-X1")

# %%
def funcion(t, X):
    x1 = X[0]
    x2 = X[1]
    dx1=x1*(3-x1-2*x2)
    dx2 = x2*(2-x2-x1)
    dx = [dx1,dx2]
    return dx
t_span = [0,20]
x0 = np.array([1.5, 1])
g = solve_ivp(funcion,t_span, x0)
g
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  8.940e-02 ...  1.948e+01  2.000e+01]
#         y: [[ 1.500e+00  1.444e+00 ...  3.004e+00  3.001e+00]
#             [ 1.000e+00  9.606e-01 ...  1.847e-07  1.092e-07]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 146
#      njev: 0
#       nlu: 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(g.t, g.y[0,:], label = "x1")
plt.plot(g.t, g.y[1,:], label = "x2")
plt.legend(loc="best")
plt.grid
plt.figure()
plt.plot(g.y[0, :], g.y[1, :], label = "X2-X1")

# %%
def funcion(t, X):
    x1 = X[0]
    x2 = X[1]
    dx1=x1*(3-x1-2*x2)
    dx2 = x2*(2-x2-x1)
    dx = [dx1,dx2]
    return dx
t_span = [0,20]
x0 = np.array([1, 1.5])
g = solve_ivp(funcion,t_span, x0)
g
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  8.125e-02 ...  1.830e+01  2.000e+01]
#         y: [[ 1.000e+00  9.289e-01 ...  3.385e-07  6.620e-08]
#             [ 1.500e+00  1.448e+00 ...  2.000e+00  2.000e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 116
#      njev: 0
#       nlu: 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(g.t, g.y[0,:], label = "x1")
plt.plot(g.t, g.y[1,:], label = "x2")
plt.legend(loc="best")
plt.grid
plt.figure()
plt.plot(g.y[0, :], g.y[1, :], label = "X2-X1")

# %%
def funcion(t, X):
    x1 = X[0]
    x2 = X[1]
    dx1=x1*(3-x1-2*x2)
    dx2 = x2*(2-x2-x1)
    dx = [dx1,dx2]
    return dx
t_span = [0,20]
x0 = np.array([1, 1])
g = solve_ivp(funcion,t_span, x0)
g
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.000e-06  1.100e-05  1.110e-04  1.111e-03
#              1.111e-02  1.111e-01  1.111e+00  1.111e+01  2.000e+01]
#         y: [[ 1.000e+00  1.000e+00 ...  1.000e+00  1.000e+00]
#             [ 1.000e+00  1.000e+00 ...  1.000e+00  1.000e+00]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 56
#      njev: 0
#       nlu: 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(g.t, g.y[0,:], label = "x1")
plt.plot(g.t, g.y[1,:], label = "x2")
plt.legend(loc="best")
plt.grid
plt.figure()
plt.plot(g.y[0, :], g.y[1, :], label = "X2-X1")

# %% [markdown]
# **Conclusión:**

# %% [markdown]
# Referencia:
# - Strogatz, Steven. *NONLINEAR DYNAMICS AND CHAOS*, ISBN: 9780813349107, (eBook disponible en biblioteca).

# %% [markdown]
# ## Ejemplo 2
#
# ### Primer punto.
# Resolver el siguiente sistema:
#
# \begin{align}
# \frac{dx}{dt} &= v \\
# \frac{dv}{dt} &= -0.7 (\frac{dx}{dt})^2 \text{sign}{(\frac{dx}{dt})} - 100 \sin{(x)},
# \end{align}
#
#
# $$ x(0) = \frac{\pi}{3}$$
# $$ v(0) = 0$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import numpy as np 
from scipy.integrate import solve_ivp, odeint

w0 = 100  # angular frequency rad/s
k = 0.7  # gamma·l, damping constant
x0 = np.pi / 3  # initial angle

def f(x, t):
    return [x[1], -k * x[1]**2 * np.sign(x[1]) - w0**2 * np.sin(x[0])]

t_span = [0, 1]
t_eval = np.linspace(t_span[0], t_span[1], 1000)
x_init = [x0, 0]

sol = odeint(f, x_init, t_eval)

# %% [markdown]
# ### Segundo punto.
# 1. Graficar $x$ vs $t$.

# %%
plt.plot(t_eval, sol[:, 0])
plt.grid(True)
plt.xlabel('t')
plt.ylabel("x")
plt.title('Damped Oscillator')
plt.show()

# %% [markdown]
# 2. Graficar $t$ vs $v$.

# %%
plt.plot(sol[:, 1],t_eval)
plt.grid(True)
plt.xlabel('v')
plt.ylabel("t")
plt.title('Damped Oscillator')
plt.show()

# %% [markdown]
# 3. Graficar $x$ vs $v$.

# %%
plt.plot(sol[:, 1],sol[:, 0])
plt.grid(True)
plt.xlabel('v')
plt.ylabel("x")
plt.title('Damped Oscillator')
plt.show()

# %% [markdown]
# ## Ejemplo 3
#
# **¿Qué es una ecuación diferencial?**

# %% [markdown]
# Una ecuación diferencial es una ecuación matemática que describe cómo cambia una cantidad en función de su valor y de la tasa de cambio de esa cantidad

# %% [markdown]
# **¿Qué es la solución de una ecuación diferencial?**

# %% [markdown]
# La solución de una ecuación diferencial es una función que satisface la ecuación diferencial.

# %% [markdown]
# **¿Qué es una condición inicial? ¿Por qué se necesita para poder resolver numéricamente una ecuación diferencial de primer orden?**

# %% [markdown]
# Una condición inicial es un valor que se utiliza para determinar la solución de una ecuación diferencial.
# Para resolver numéricamente una ecuación diferencial de primer orden, se necesita una condición inicial porque la solución de una ecuación diferencial de primer orden es una función que tiene una constante arbitraria que se determina a partir de la condición inicial

# %% [markdown]
# **Si tuviera un sistema de 3 ecuaciones diferenciales con 3 variables diferentes, ¿cuántas condiciones iniciales se necesitan? ¿Por qué?**

# %% [markdown]
# Si tuviera un sistema de 3 ecuaciones diferenciales con 3 variables diferentes, se necesitarían 3 condiciones iniciales. Esto se debe a que cada ecuación diferencial en el sistema tiene una constante arbitraria que se determina a partir de una condición inicial. Por lo tanto, se necesitan 3 condiciones iniciales para determinar las 3 constantes arbitrarias.

# %% [markdown]
# **¿Cuál es la diferencia entre los siguientes tipos de errores?**
# - Norma del error
# - Error cuadrático medio
# - Integral del error cuadrático

# %% [markdown]
#  La norma del error es una medida de la distancia entre dos vectores. El error cuadrático medio es una medida de la diferencia entre dos conjuntos de datos. La integral del error cuadrático es una medida de la diferencia entre dos funciones.
